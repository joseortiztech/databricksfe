# %%
from pyspark.sql import Row

usuarios = [
    Row(
        nickname=f"user{i}",
        nombre=f"Nombre{i}",
        apellido=f"Apellido{i}",
        direccion=f"Calle {i} # {100+i}, Ciudad{i}",
        email=f"user{i}@correo.com"
    )
    for i in range(1, 51)
]

df_usuarios = spark.createDataFrame(usuarios)
display(df_usuarios)
